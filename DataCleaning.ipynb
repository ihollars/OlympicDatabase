# %% [markdown]
# # Cleaning and Formatting Olympic Dataset for Upload:

# %%
import pandas as pd
import re
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/Users/isaiahhollars/Desktop/olympicProject/athlete_events.csv")

# %% [markdown]
# ## Add Event Gender Column

# %%
conditions = [
    (df['Event'].str.contains("Men's")),
    (df['Event'].str.contains("Women's")),
    (df['Event'].str.contains("Mixed")) 
    ]

# create a list of the values we want to assign for each condition
values = ["Men's", "Women's", "Mixed"]

# create a new column and use np.select to assign values to it using our lists as arguments
df['EventGender'] = np.select(conditions, values)

# display updated DataFrame
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal EventGender
# 0       Basketball Men's Basketball   NaN       Men's
# 1      Judo Men's Extra-Lightweight   NaN       Men's
# 2           Football Men's Football   NaN       Men's
# 3       Tug-Of-War Men's Tug-Of-War  Gold       Men's
# 4  Speed Skating Women's 500 metres   NaN     Women's

# %% [markdown]
# ## Change the Event Column to exclude the gender

# %%
conditions = [
    (df['Event'].str.contains("Men's")),
    (df['Event'].str.contains("Women's")),
    (df['Event'].str.contains("Mixed")) 
    ]

# create a list of the values we want to assign for each condition
values = [df['Event'].str.replace("Men's ",''),
          df['Event'].str.replace("Women's ",''),
         df['Event'].str.replace("Mixed " ,',') ]

# create a new column and use np.select to assign values to it using our lists as arguments
df['Event'] = np.select(conditions, values)

# display updated DataFrame
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                       Event Medal EventGender
# 0     Basketball Basketball   NaN       Men's
# 1    Judo Extra-Lightweight   NaN       Men's
# 2         Football Football   NaN       Men's
# 3     Tug-Of-War Tug-Of-War  Gold       Men's
# 4  Speed Skating 500 metres   NaN     Women's

# %% [markdown]
# ## Take out redundency in Event Column

# %%
def removeDouble(row):
    return row['Event'].replace(row['Sport'], '')

def addBack(row):
    if row['Event2']==' ' or row['Event2']=='' or row['Event2']==',':
        return row['Sport'].strip()     
    else: return row['Event2'].replace(',','' ).strip()

    
def fixEmpty(row):
    if row['Event2']=='':
        return row['Sport']
    else: 
        return row['Event2']
    
    
def fixLugeGender(row):
    if row['Event2']=="(Men)'s Doubles":
        return "Men's"
    else:
        return row['EventGender']
    
    
def fixLugeEvent(row):
    if row['Event2']=="(Men)'s Doubles":
        return "Doubles"
    else:
        return row['Event2']


    
df["Event2"] = df.apply(removeDouble, axis=1)  
df['Event2'] = df.apply(addBack, axis=1)
df['Event2'] = df.apply(fixEmpty, axis=1)
df['EventGender']=df.apply(fixLugeGender, axis=1)
df['Event2']=df.apply(fixLugeEvent, axis=1)

df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                       Event Medal EventGender             Event2
# 0     Basketball Basketball   NaN       Men's         Basketball
# 1    Judo Extra-Lightweight   NaN       Men's  Extra-Lightweight
# 2         Football Football   NaN       Men's           Football
# 3     Tug-Of-War Tug-Of-War  Gold       Men's         Tug-Of-War
# 4  Speed Skating 500 metres   NaN     Women's         500 metres

# %% [markdown]
# ## change age, height, weight, to ints for SQL to handel better

# %%
df['Age'] = df['Age'].fillna(0)
df['Height'] = df['Height'].fillna(0)
df['Weight'] = df['Weight'].fillna(0)
df['Medal'] = df['Medal'].fillna("None") #also replace null with "None" for medal string

# %%
df['Age'] = df['Age'].astype(int)
df['Height'] = df['Height'].astype(int)
df['Weight'] = df['Weight'].astype(int)

# %% [markdown]
# ## Now it's time for first and Last names...

# %%
def fname(row): 
    return row['Name'].split(' ')[0]
def lname(row):
    return row['Name'].split(' ')[-1]

# %%
df['Ath_FN']=df.apply (lambda row: fname(row), axis=1)
df['Ath_LN']= df.apply (lambda row: lname(row), axis=1)
df.head()
# Out:
#    ID                      Name Sex  Age  Height  Weight            Team  NOC  \
# 0   1                 A Dijiang   M   24     180      80           China  CHN
# 1   2                  A Lamusi   M   23     170      60           China  CHN
# 2   3       Gunnar Nielsen Aaby   M   24       0       0         Denmark  DEN
# 3   4      Edgar Lindenau Aabye   M   34       0       0  Denmark/Sweden  DEN
# 4   5  Christine Jacoba Aaftink   F   21     185      82     Netherlands  NED
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                       Event Medal EventGender             Event2     Ath_FN  \
# 0     Basketball Basketball  None       Men's         Basketball          A
# 1    Judo Extra-Lightweight  None       Men's  Extra-Lightweight          A
# 2         Football Football  None       Men's           Football     Gunnar
# 3     Tug-Of-War Tug-Of-War  Gold       Men's         Tug-Of-War      Edgar
# 4  Speed Skating 500 metres  None     Women's         500 metres  Christine
#
#     Ath_LN
# 0  Dijiang
# 1   Lamusi
# 2     Aaby
# 3    Aabye
# 4  Aaftink

# %% [markdown]
# ## make games csv file

# %%
dfGames = df[['City','Season','Year']]

# %%
dfGames=dfGames.drop_duplicates()
dfGames.describe()
# Out:
#               Year
# count    52.000000
# mean   1963.115385
# std      34.034385
# min    1896.000000
# 25%    1935.000000
# 50%    1966.000000
# 75%    1992.000000
# max    2016.000000

# %%
dfGames['GamesID'] = [i for i in range(1,len(dfGames.index)+1)]

# %%
dfGames.head()
# Out:
#         City  Season  Year  GamesID
# 0  Barcelona  Summer  1992        1
# 1     London  Summer  2012        2
# 2  Antwerpen  Summer  1920        3
# 3      Paris  Summer  1900        4
# 4    Calgary  Winter  1988        5

# %%
dfGames = dfGames[['GamesID','City','Season','Year']] #reorder 

#rename: 
dfGames = dfGames.rename(columns={ 'City':'Games_City','Season':'Games_Season','Year':'Games_Year'})

# %%
dfGames.head()
# Out:
#    GamesID Games_City Games_Season  Games_Year
# 0        1  Barcelona       Summer        1992
# 1        2     London       Summer        2012
# 2        3  Antwerpen       Summer        1920
# 3        4      Paris       Summer        1900
# 4        5    Calgary       Winter        1988

# %%
dfGames.to_csv('/Users/isaiahhollars/Desktop/olympicProject/GamesTable', sep='\t', encoding='utf-8', header=True, index=False)

# %% [markdown]
# ## make athlete csv file

# %%
dfAth = df[['ID','Ath_FN','Ath_LN','Sex','Age','Height','Weight','Year']]
dfAth.head(1)
# Out:
#    ID Ath_FN   Ath_LN Sex  Age  Height  Weight  Year
# 0   1      A  Dijiang   M   24     180      80  1992

# %%
dfAth.replace(')', value='')
dfAth.replace('(', value='')
dfAth.replace(' ', value='')
# Out:
#             ID     Ath_FN   Ath_LN Sex  Age  Height  Weight  Year
# 0            1          A  Dijiang   M   24     180      80  1992
# 1            2          A   Lamusi   M   23     170      60  2012
# 2            3     Gunnar     Aaby   M   24       0       0  1920
# 3            4      Edgar    Aabye   M   34       0       0  1900
# 4            5  Christine  Aaftink   F   21     185      82  1988
# ...        ...        ...      ...  ..  ...     ...     ...   ...
# 271111  135569    Andrzej       ya   M   29     179      89  1976
# 271112  135570      Piotr       ya   M   27     176      59  2014
# 271113  135570      Piotr       ya   M   27     176      59  2014
# 271114  135571     Tomasz       ya   M   30     185      96  1998
# 271115  135571     Tomasz       ya   M   34     185      96  2002
#
# [271116 rows x 8 columns]

# %%
#drop repeats df.drop_duplicates(subset=['brand'])
dfAth.drop_duplicates(subset=['ID'], inplace=True)
dfAth.head(1)
# Out:
# /Users/isaiahhollars/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    ID Ath_FN   Ath_LN Sex  Age  Height  Weight  Year
# 0   1      A  Dijiang   M   24     180      80  1992

# %%
def yob(row):
    return row['Year']-row['Age']

dfAth['Ath_YOB']= dfAth.apply (lambda row: yob(row), axis=1)

dfAth.head(1)
# Out:
# /Users/isaiahhollars/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#    ID Ath_FN   Ath_LN Sex  Age  Height  Weight  Year  Ath_YOB
# 0   1      A  Dijiang   M   24     180      80  1992     1968

# %%
dfAth = dfAth.astype({"ID": int, "Ath_YOB": int, 'Height':int, 'Weight':int})

# %%
dfAth.dtypes
# Out:
# ID          int64
# Ath_FN     object
# Ath_LN     object
# Sex        object
# Age         int64
# Height      int64
# Weight      int64
# Year        int64
# Ath_YOB     int64
# dtype: object

# %%
#rename: 
dfAth = dfAth.rename(columns={ 'ID':'AthID','Sex':'Ath_Sex','Age':'Ath_Age','Height':'Ath_Height','Weight':'Ath_Weight'})
dfAth.head(1)
# Out:
#    AthID Ath_FN   Ath_LN Ath_Sex  Ath_Age  Ath_Height  Ath_Weight  Year  \
# 0      1      A  Dijiang       M       24         180          80  1992
#
#    Ath_YOB
# 0     1968

# %%
#reorder
dfAth = dfAth[['AthID','Ath_FN','Ath_LN','Ath_Sex','Ath_YOB','Ath_Height','Ath_Weight']] #reorder 
dfAth.head(1)
# Out:
#    AthID Ath_FN   Ath_LN Ath_Sex  Ath_YOB  Ath_Height  Ath_Weight
# 0      1      A  Dijiang       M     1968         180          80

# %%
dfAth['Ath_FN'] = df['Ath_FN'].str.strip()
dfAth['Ath_LN'] = df['Ath_LN'].str.strip()

# %%
dfAth.to_csv('/Users/isaiahhollars/Desktop/olympicProject/AthTable', sep='\t', encoding='utf-8', header=True, index=False)

# %%
dfAth.tail(10)
# Out:
#          AthID     Ath_FN      Ath_LN Ath_Sex  Ath_YOB  Ath_Height  Ath_Weight
# 271101  135562      Milan        Zyka       M     1948         173          68
# 271102  135563     Olesya      Zykina       F     1981         171          64
# 271104  135564    Yevgeny       Zykov       M     1980         172          65
# 271105  135565   Fernando  Zylberberg       M     1977         168          76
# 271107  135566      James      Zylker       M     1951         175          75
# 271108  135567  Aleksandr      Zyuzin       M     1976         183          72
# 271110  135568       Olga    Zyuzkova       F     1983         171          69
# 271111  135569    Andrzej          ya       M     1947         179          89
# 271112  135570      Piotr          ya       M     1987         176          59
# 271114  135571     Tomasz          ya       M     1968         185          96

# %% [markdown]
# ## TEAM table

# %%
regions = pd.read_csv("/Users/isaiahhollars/Desktop/olympicProject/noc_regions.csv")
regions.head(1)
# Out:
#    NOC       region notes
# 0  AFG  Afghanistan   NaN

# %%
regions=regions[['NOC','region']]

# %%
#rename: 
regions = regions.rename(columns={ 'NOC':'TeamNOC','region':'Team_Region'})

# %%
regions.drop_duplicates(subset=['TeamNOC'],inplace=True)
regions.head(1)
# Out:
#   TeamNOC  Team_Region
# 0     AFG  Afghanistan

# %%
regions.shape
# Out:
# (230, 2)

# %%
temp = df.rename(columns={'NOC':'TeamNOC'})
temp=temp[['TeamNOC']]
temp.drop_duplicates(subset=['TeamNOC'], inplace = True)
temp.head(5)
# Out:
#    TeamNOC
# 0      CHN
# 2      DEN
# 4      NED
# 10     USA
# 28     FIN

# %%
temp.shape
# Out:
# (230, 1)

# %%
#bigdata = pd.concat([data1, data2], ignore_index=True, sort=False)
join = pd.concat([regions,temp],ignore_index=True, sort=False)
join.shape
join.head()
# Out:
#   TeamNOC  Team_Region
# 0     AFG  Afghanistan
# 1     AHO      Curacao
# 2     ALB      Albania
# 3     ALG      Algeria
# 4     AND      Andorra

# %%
join.drop_duplicates(subset=['TeamNOC'],inplace=True)
join[join['Team_Region'].isna()]
# Out:
#     TeamNOC Team_Region
# 168     ROT         NaN
# 208     TUV         NaN
# 213     UNK         NaN
# 295     SGP         NaN

# %%
#now we have the extra entry we were missing in the NOC
join.shape
# Out:
# (231, 2)

# %%
#df[df['column name'].isna()]
#temp2[temp2['Team_Region'].isna()]
# Out:
#        TeamNOC Team_Region
# 264737     ROT         NaN
# 270680     UNK         NaN
# 270682     TUV         NaN

# %%
#temp2.shape
# Out:
# (229, 2)

# %%
join.to_csv('/Users/isaiahhollars/Desktop/olympicProject/TeamTable', sep='\t', encoding='utf-8', header=True, index=False)

# %% [markdown]
# ## Event Table - references the Games table

# %%
df.head(2)
# Out:
#    ID       Name Sex  Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M   24     180      80  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M   23     170      60  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                   Event Medal EventGender  \
# 0  Summer  Barcelona  Basketball   Basketball Basketball  None       Men's
# 1  Summer     London        Judo  Judo Extra-Lightweight  None       Men's
#
#               Event2 Ath_FN   Ath_LN
# 0         Basketball      A  Dijiang
# 1  Extra-Lightweight      A   Lamusi

# %%
ev = df[['Sport','Event2','EventGender','Year','Season']]
ev = ev.rename(columns={ 'Sport':'Ev_Sport','Event2':'Ev_Name','EventGender':'Ev_Gender','Year':'Games_Year','Season':'Games_Season'})
ev.head()
# Out:
#         Ev_Sport            Ev_Name Ev_Gender  Games_Year Games_Season
# 0     Basketball         Basketball     Men's        1992       Summer
# 1           Judo  Extra-Lightweight     Men's        2012       Summer
# 2       Football           Football     Men's        1920       Summer
# 3     Tug-Of-War         Tug-Of-War     Men's        1900       Summer
# 4  Speed Skating         500 metres   Women's        1988       Winter

# %%
#need to capture the gameID from the game table: 
dfGames.head(1)
# Out:
#    GamesID Games_City Games_Season  Games_Year
# 0        1  Barcelona       Summer        1992

# %%
#merged_data= df1.merge(df2, on=["column1","column2"])

Eventdf = ev.merge(dfGames,  on=['Games_Year','Games_Season'])
Eventdf.sample(10)
# Out:
#            Ev_Sport                                     Ev_Name Ev_Gender  \
# 119724      Cycling                        Road Race Individual     Men's
# 110896  Ski Jumping                             Large Hill Team     Men's
# 191451     Shooting  Small-Bore Rifle Three Positions 50 metres     Men's
# 164611   Volleyball                                  Volleyball   Women's
# 11614    Basketball                                  Basketball   Women's
# 145442     Shooting                   Sporting Pistol 25 metres   Women's
# 18240      Handball                                    Handball   Women's
# 229524       Diving                                 Springboard     Men's
# 188221    Athletics                        4 x 100 metres Relay   Women's
# 94432    Gymnastics                                  Side Horse     Men's
#
#         Games_Year Games_Season  GamesID   Games_City
# 119724        2008       Summer       20      Beijing
# 110896        2006       Winter       19       Torino
# 191451        1988       Summer       29        Seoul
# 164611        1984       Summer       26  Los Angeles
# 11614         1992       Summer        1    Barcelona
# 145442        2004       Summer       22       Athina
# 18240         2012       Summer        2       London
# 229524        1928       Summer       35    Amsterdam
# 188221        1972       Summer       28       Munich
# 94432         1924       Summer       15        Paris

# %%
Eventdf=Eventdf[['Ev_Sport','Ev_Gender','Ev_Name','GamesID']]
Eventdf.head()
# Out:
#         Ev_Sport Ev_Gender                Ev_Name  GamesID
# 0     Basketball     Men's             Basketball        1
# 1        Sailing     Men's      Two Person Dinghy        1
# 2  Equestrianism     Mixed     Jumping Individual        1
# 3      Wrestling     Men's  Heavyweight Freestyle        1
# 4           Judo     Men's      Half-Middleweight        1

# %%
Eventdf.drop_duplicates(inplace=True)
Eventdf.head()
# Out:
#         Ev_Sport Ev_Gender                Ev_Name  GamesID
# 0     Basketball     Men's             Basketball        1
# 1        Sailing     Men's      Two Person Dinghy        1
# 2  Equestrianism     Mixed     Jumping Individual        1
# 3      Wrestling     Men's  Heavyweight Freestyle        1
# 4           Judo     Men's      Half-Middleweight        1

# %%
Eventdf['EvID'] = [i for i in range(1,len(Eventdf.index)+1)]
Eventdf=Eventdf[['EvID','Ev_Sport','Ev_Gender','Ev_Name','GamesID']] #reorder 
Eventdf.head()
# Out:
#    EvID       Ev_Sport Ev_Gender                Ev_Name  GamesID
# 0     1     Basketball     Men's             Basketball        1
# 1     2        Sailing     Men's      Two Person Dinghy        1
# 2     3  Equestrianism     Mixed     Jumping Individual        1
# 3     4      Wrestling     Men's  Heavyweight Freestyle        1
# 4     5           Judo     Men's      Half-Middleweight        1

# %%
Eventdf.loc[Eventdf['GamesID']==52]
# Out:
#         EvID       Ev_Sport Ev_Gender                         Ev_Name  GamesID
# 209657  4609       Shooting     Men's                            Trap       52
# 209659  4611        Cycling     Men's            Road Race Individual       52
# 209661  4613        Cycling     Men's                  Road Race Team       52
# 209663  4615  Weightlifting     Men's                     Lightweight       52
# 209665  4617       Swimming   Women's  4 x 100 metres Freestyle Relay       52
# ...      ...            ...       ...                             ...      ...
# 211393  4901      Wrestling     Men's           Heavyweight Freestyle       52
# 211935  4903      Wrestling     Men's         Featherweight Freestyle       52
# 211997  4905       Swimming   Women's         200 metres Breaststroke       52
# 212221  4907         Rowing     Men's                   Single Sculls       52
# 213819  4909         Boxing     Men's              Light-Middleweight       52
#
# [151 rows x 5 columns]

# %%
Eventdf.tail()
# Out:
#         EvID   Ev_Sport Ev_Gender                  Ev_Name  GamesID
# 275960  6339  Athletics     Men's             Discus Throw       51
# 275962  6340    Fencing     Men's         Sabre Individual       51
# 276021  6341    Cycling     Men's            12-Hours Race       51
# 276028  6342   Swimming     Men's     500 metres Freestyle       51
# 276123  6343    Fencing     Men's  Foil Masters Individual       51

# %%
df.loc[df['City']=='Stockholm'].loc[df['Year']==1956]
# Out:
#             ID                                       Name Sex  Age  Height  \
# 6194      3479            Karl Vilhelm Nordstrm Ammitzbll   M   40       0
# 6195      3479            Karl Vilhelm Nordstrm Ammitzbll   M   40       0
# 6663      3728                    Hans Christian Andersen   M   42       0
# 6664      3728                    Hans Christian Andersen   M   42       0
# 8370      4608  Kaarlo Erkki Kustavi Anttinen (Andersin-)   M   41     180
# ...        ...                                        ...  ..  ...     ...
# 261838  130999                         Hans Gnter Winkler   M   29     174
# 267427  133796                         Mohamed Selim Zaki   M   31       0
# 267428  133796                         Mohamed Selim Zaki   M   31       0
# 270202  135175                              Hermann Zobel   M   47       0
# 270203  135175                              Hermann Zobel   M   47       0
#
#         Weight     Team  NOC        Games  Year  Season       City  \
# 6194         0  Denmark  DEN  1956 Summer  1956  Summer  Stockholm
# 6195         0  Denmark  DEN  1956 Summer  1956  Summer  Stockholm
# 6663         0  Denmark  DEN  1956 Summer  1956  Summer  Stockholm
# 6664         0  Denmark  DEN  1956 Summer  1956  Summer  Stockholm
# 8370        77  Finland  FIN  1956 Summer  1956  Summer  Stockholm
# ...        ...      ...  ...          ...   ...     ...        ...
# 261838      72  Germany  GER  1956 Summer  1956  Summer  Stockholm
# 267427       0    Egypt  EGY  1956 Summer  1956  Summer  Stockholm
# 267428       0    Egypt  EGY  1956 Summer  1956  Summer  Stockholm
# 270202       0  Denmark  DEN  1956 Summer  1956  Summer  Stockholm
# 270203       0  Denmark  DEN  1956 Summer  1956  Summer  Stockholm
#
#                 Sport                                      Event Medal  \
# 6194    Equestrianism  Equestrianism Three-Day Event, Individual  None
# 6195    Equestrianism        Equestrianism Three-Day Event, Team  None
# 6663    Equestrianism  Equestrianism Three-Day Event, Individual  None
# 6664    Equestrianism        Equestrianism Three-Day Event, Team  None
# 8370    Equestrianism  Equestrianism Three-Day Event, Individual  None
# ...               ...                                        ...   ...
# 261838  Equestrianism               Equestrianism ,Jumping, Team  Gold
# 267427  Equestrianism         Equestrianism ,Jumping, Individual  None
# 267428  Equestrianism               Equestrianism ,Jumping, Team  None
# 270202  Equestrianism        Equestrianism ,Dressage, Individual  None
# 270203  Equestrianism              Equestrianism ,Dressage, Team  None
#
#        EventGender                      Event2   Ath_FN       Ath_LN
# 6194         Men's  Three-Day Event Individual     Karl    Ammitzbll
# 6195         Men's        Three-Day Event Team     Karl    Ammitzbll
# 6663         Men's  Three-Day Event Individual     Hans     Andersen
# 6664         Men's        Three-Day Event Team     Hans     Andersen
# 8370         Men's  Three-Day Event Individual   Kaarlo  (Andersin-)
# ...            ...                         ...      ...          ...
# 261838       Mixed                Jumping Team     Hans      Winkler
# 267427       Mixed          Jumping Individual  Mohamed         Zaki
# 267428       Mixed                Jumping Team  Mohamed         Zaki
# 270202       Mixed         Dressage Individual  Hermann        Zobel
# 270203       Mixed               Dressage Team  Hermann        Zobel
#
# [298 rows x 19 columns]

# %%
Eventdf.to_csv('/Users/isaiahhollars/Desktop/olympicProject/EventTable', sep='\t', encoding='utf-8', header=True, index=False)

# %% [markdown]
# # Final Boss: Make the Score Table

# %%
df.head(1)
# Out:
#    ID       Name Sex  Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M   24     180      80  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                  Event Medal EventGender  \
# 0  Summer  Barcelona  Basketball  Basketball Basketball  None       Men's
#
#        Event2 Ath_FN   Ath_LN
# 0  Basketball      A  Dijiang

# %%
#merged_data= df1.merge(df2, on=["column1","column2"])
evgam = Eventdf.merge(dfGames, on=['GamesID'])
evgam.head(1)
# Out:
#    EvID    Ev_Sport Ev_Gender     Ev_Name  GamesID Games_City Games_Season  \
# 0     1  Basketball     Men's  Basketball        1  Barcelona       Summer
#
#    Games_Year
# 0        1992

# %%
score = df.rename(columns={ 'Sport':'Ev_Sport','Event2':'Ev_Name','EventGender':'Ev_Gender','Year':'Games_Year','Season':'Games_Season'})
score.head(1)
# Out:
#    ID       Name Sex  Age  Height  Weight   Team  NOC        Games  \
# 0   1  A Dijiang   M   24     180      80  China  CHN  1992 Summer
#
#    Games_Year Games_Season       City    Ev_Sport                  Event  \
# 0        1992       Summer  Barcelona  Basketball  Basketball Basketball
#
#   Medal Ev_Gender     Ev_Name Ath_FN   Ath_LN
# 0  None     Men's  Basketball      A  Dijiang

# %%
score1 = score.merge(evgam, on=['Ev_Sport','Ev_Name','Ev_Gender','Games_Year','Games_Season'])

# %%
score.shape
# Out:
# (271116, 19)

# %%
score1.shape
# Out:
# (276243, 22)

# %%
score1.drop_duplicates(inplace=True)
score1.shape
# Out:
# (274858, 22)

# %%
score1.head()
# Out:
#      ID                     Name Sex  Age  Height  Weight     Team  NOC  \
# 0     1                A Dijiang   M   24     180      80    China  CHN
# 1  2256           Vladan Alanovi   M   25     190      81  Croatia  CRO
# 2  2424   Santiago Aldama Aleson   M   23     213      98    Spain  ESP
# 3  4120             Armin Andres   M   33     180      76  Germany  GER
# 4  4140  Enrique Andreu Balbuena   M   24     210     102    Spain  ESP
#
#          Games  Games_Year Games_Season       City    Ev_Sport  \
# 0  1992 Summer        1992       Summer  Barcelona  Basketball
# 1  1992 Summer        1992       Summer  Barcelona  Basketball
# 2  1992 Summer        1992       Summer  Barcelona  Basketball
# 3  1992 Summer        1992       Summer  Barcelona  Basketball
# 4  1992 Summer        1992       Summer  Barcelona  Basketball
#
#                    Event   Medal Ev_Gender     Ev_Name    Ath_FN    Ath_LN  \
# 0  Basketball Basketball    None     Men's  Basketball         A   Dijiang
# 1  Basketball Basketball  Silver     Men's  Basketball    Vladan   Alanovi
# 2  Basketball Basketball    None     Men's  Basketball  Santiago    Aleson
# 3  Basketball Basketball    None     Men's  Basketball     Armin    Andres
# 4  Basketball Basketball    None     Men's  Basketball   Enrique  Balbuena
#
#    EvID  GamesID Games_City
# 0     1        1  Barcelona
# 1     1        1  Barcelona
# 2     1        1  Barcelona
# 3     1        1  Barcelona
# 4     1        1  Barcelona

# %%
score2= score1[['ID','EvID','Medal','NOC']]
score2=score2.rename(columns={'ID':'AthID','NOC':'TeamNOC'})
score2.head()
# Out:
#    AthID  EvID   Medal TeamNOC
# 0      1     1    None     CHN
# 1   2256     1  Silver     CRO
# 2   2424     1    None     ESP
# 3   4120     1    None     GER
# 4   4140     1    None     ESP

# %%
score2.shape
# Out:
# (274858, 4)

# %%
score2.drop_duplicates(subset=['AthID','EvID'], inplace=True)
score2.shape
# Out:
# (274763, 4)

# %%
score2.head()
# Out:
#    AthID  EvID   Medal TeamNOC
# 0      1     1    None     CHN
# 1   2256     1  Silver     CRO
# 2   2424     1    None     ESP
# 3   4120     1    None     GER
# 4   4140     1    None     ESP

# %%
score2.to_csv('/Users/isaiahhollars/Desktop/olympicProject/ScoreTable', sep='\t', encoding='utf-8', header=True, index=False)
