# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
df6=pd.read_json('./query_json_files/q6.json')

# %%
topdf6 = df6.head(10)
topdf6
# Out:
#                     Ev_Sport  Average Age
# 0        Rhythmic Gymnastics           18
# 1                   Swimming           20
# 2                 Gymnastics           22
# 3             Figure Skating           22
# 4  Short Track Speed Skating           22
# 5                     Diving           22
# 6      Synchronized Swimming           22
# 7                   Football           23
# 8                Ski Jumping           23
# 9                     Boxing           23

# %%
fig, ax = plt.subplots()
fig.set_size_inches(4,12)
sns.set_context('paper',font_scale=1.7)
ax = sns.barplot(data=topdf6,y='Ev_Sport', x='Average Age', color='b')
ax.set_xlabel('Average Age',fontsize=25);
ax.set_ylabel('Sport',fontsize=25)
ax.set_title('Top 10 Youngest Olympic Sports by Average Age', fontsize=25)
ax.bar_label(ax.containers[0]);

# %%
fig.savefig("q6part1.png",bbox_inches='tight')

# %% [markdown]
# new graph for problem 6 based on teens

# %%
df6_2=pd.read_json('./query_json_files/q6_2.json')
df6_2.head(10)
# Out:
#                     Ev_Sport  Teen_Percentage
# 0        Rhythmic Gymnastics            32.52
# 1                   Swimming            20.89
# 2             Figure Skating            15.80
# 3                 Gymnastics            14.03
# 4                     Diving            11.49
# 5                    Croquet            10.53
# 6  Short Track Speed Skating             6.84
# 7      Synchronized Swimming             5.72
# 8              Alpine Skiing             5.33
# 9                Ski Jumping             4.71

# %%
fig, ax = plt.subplots()
fig.set_size_inches(4,12)
sns.set_context('paper',font_scale=1.5)
ax = sns.barplot(data=df6_2.head(10),y='Ev_Sport', x='Teen_Percentage', color='b')
ax.set_title('Top 10 Youngest Olympic Sports by Teen-Percentage', fontsize=25)
ax.set_xlabel('Percent of Athletes Under 18',fontsize=25);
ax.set_ylabel('Sport',fontsize=25)
ax.bar_label(ax.containers[0]);

# %%
fig.savefig("q6part2.png",bbox_inches='tight')

# %%
df7=pd.read_json('./query_json_files/q7.json')
df7.head(15)
# Out:
#    Average Age Ath_Sex             Ev_Sport
# 0           21       F               Diving
# 1           23       M               Diving
# 2           20       F       Figure Skating
# 3           23       M       Figure Skating
# 4           19       F           Gymnastics
# 5           24       M           Gymnastics
# 6           18       F  Rhythmic Gymnastics
# 7           19       F             Swimming
# 8           21       M             Swimming

# %%
df7.drop(index=6, inplace=True)
df7.head(10)
# Out:
#    Average Age Ath_Sex        Ev_Sport
# 0           21       F          Diving
# 1           23       M          Diving
# 2           20       F  Figure Skating
# 3           23       M  Figure Skating
# 4           19       F      Gymnastics
# 5           24       M      Gymnastics
# 7           19       F        Swimming
# 8           21       M        Swimming

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.set_context('talk',font_scale=1.4)
ax = sns.barplot(data=df7,y='Average Age', x='Ev_Sport',hue='Ath_Sex')
ax.set_title('Comparing Male and Female Average Ages in Diving,Figure Skating, Gymnastics, and Swimming', fontsize=25)
ax.set_xlabel('Sport',fontsize=25);
ax.set_ylabel('Avereage Age',fontsize=25);

# %%
fig.savefig("q7.png",bbox_inches='tight')

# %% [markdown]
# time for question 8!!!

# %%
df8 = pd.read_json('./query_json_files/8part1.json')
df8.head()
# Out:
#    Average Age  Games_Year
# 0           23        1896
# 1           28        1900
# 2           26        1904
# 3           27        1906
# 4           27        1908

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.set_context('paper',font_scale=2)
ax = sns.lineplot(data=df8,y='Average Age', x='Games_Year',linewidth=5)
ax.set_title('Average Age of Athletes Over Time', fontsize=25)
ax.set_xlabel('Year of Olympics',fontsize=20);
ax.set_ylabel('Avereage Age of Athletes',fontsize=20);

# %%
fig.savefig("q8part1.png",bbox_inches='tight')

# %%
df8part2 = pd.read_json('./query_json_files/q8part2.json')
df8part2.head(15)
# Out:
#     Average Age  Games_Year        Ev_Sport
# 0            24        1896      Gymnastics
# 1            18        1896        Swimming
# 2            22        1900      Gymnastics
# 3            21        1900        Swimming
# 4            23        1904          Diving
# 5            25        1904      Gymnastics
# 6            22        1904        Swimming
# 7            22        1906        Swimming
# 8            24        1906      Gymnastics
# 9            26        1906          Diving
# 10           28        1908  Figure Skating
# 11           24        1908          Diving
# 12           23        1908      Gymnastics
# 13           21        1908        Swimming
# 14           24        1912      Gymnastics

# %%
gym= df8part2.loc[df8part2['Ev_Sport']=='Gymnastics']
swim=df8part2.loc[df8part2['Ev_Sport']=='Swimming']
dive=df8part2.loc[df8part2['Ev_Sport']=='Diving']
figskate=df8part2.loc[df8part2['Ev_Sport']=='Figure Skating']
total = pd.merge(gym,swim,on=['Games_Year'])
total = pd.merge(total,dive,on=['Games_Year'])
total = pd.merge(total,figskate,on=['Games_Year'])
total.head()
# Out:
#    Average Age_x  Games_Year  Ev_Sport_x  Average Age_y Ev_Sport_y  \
# 0             23        1908  Gymnastics             21   Swimming
# 1             26        1920  Gymnastics             22   Swimming
# 2             27        1924  Gymnastics             20   Swimming
# 3             25        1928  Gymnastics             20   Swimming
# 4             23        1932  Gymnastics             20   Swimming
#
#    Average Age_x Ev_Sport_x  Average Age_y      Ev_Sport_y
# 0             24     Diving             28  Figure Skating
# 1             23     Diving             31  Figure Skating
# 2             23     Diving             27  Figure Skating
# 3             22     Diving             27  Figure Skating
# 4             20     Diving             25  Figure Skating

# %%
total.columns = ['gym_age','games_year','gymnastics','swim_age','Swimming','dive_age','Diving','figskate_age','fig skate']
total.head()
# Out:
#    gym_age  games_year  gymnastics  swim_age  Swimming  dive_age  Diving  \
# 0       23        1908  Gymnastics        21  Swimming        24  Diving
# 1       26        1920  Gymnastics        22  Swimming        23  Diving
# 2       27        1924  Gymnastics        20  Swimming        23  Diving
# 3       25        1928  Gymnastics        20  Swimming        22  Diving
# 4       23        1932  Gymnastics        20  Swimming        20  Diving
#
#    figskate_age       fig skate
# 0            28  Figure Skating
# 1            31  Figure Skating
# 2            27  Figure Skating
# 3            27  Figure Skating
# 4            25  Figure Skating

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.set_context('paper',font_scale=2)
ax = sns.lineplot(data=total,y='gym_age', x='games_year',linewidth=5)
sns.lineplot(data=total,y='swim_age', x='games_year', ax=ax,linewidth=5)
sns.lineplot(data=total,y='dive_age', x='games_year', ax=ax,linewidth=5)
sns.lineplot(data=total,y='figskate_age', x='games_year', ax=ax,linewidth=5)

ax.set_xlabel('Year of Olympics',fontsize=20);
ax.set_ylabel('Avereage Age of Athletes',fontsize=20)
ax.set_title('Average Age of Athletes Over Time by Sport', fontsize=20)

#plt.text(x=1904,y=22.8,s='Gymnastics',fontsize=15)
#plt.text(x=1910,y=21,s='Swimming',fontsize=20)
plt.legend(title='Sport', loc='upper right', \
           labels=['Gymnastics', 'Swimming','Diving','Figure Skating'],\
          prop={'size': 25});

# %%
fig.savefig("q8part2.png",bbox_inches='tight')

# %% [markdown]
# part3 plot of teen percentage vs time

# %%
df9 = pd.read_json('./query_json_files/q9part3.json')
df9.head()
# Out:
#    Games_Year  Teen_Percentage
# 0        1896             1.58
# 1        1900             1.92
# 2        1904             2.38
# 3        1906             1.96
# 4        1908             1.66

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.set_context('paper',font_scale=2)
ax = sns.lineplot(data=df9,y='Teen_Percentage', x='Games_Year',linewidth=5)
ax.set_title('Teen-Percentage of Atheltes Over Time', fontsize=25)
ax.set_xlabel('Year of Olympics',fontsize=20);
ax.set_ylabel('Percent of Athletes that are Under 18',fontsize=20);

# %%
fig.savefig("q9part3.png",bbox_inches='tight')

# %% [markdown]
# ### question 10 time yo swag

# %%
df10 = pd.read_json('./query_json_files/q10.json')
df10.head()
# Out:
#    average_age       Team_Region  total_athletes
# 0           20          Maldives              49
# 1           20  Marshall Islands              14
# 2           21             Niger              47
# 3           21          Kiribati              11
# 4           21              Laos              54

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.set_context('paper',font_scale=2)
ax = sns.scatterplot(data=df10, x='total_athletes', y='average_age',s=200)
ax.set_title('Participation in Olympics vs Average age of Athlete by Country', fontsize=25)
ax.set_xlabel('Number of Athlete-Events in Olympic History (by Country)',fontsize=20);
ax.set_ylabel('Average Age of Athletes (in Country)',fontsize=20);

# %%
fig.savefig("q10scatter.png",bbox_inches='tight')

# %% [markdown]
# Time for the bar graphs of individual countries i gues...

# %%
df10.head(1)
# Out:
#    average_age Team_Region  total_athletes
# 0           20    Maldives              49

# %%
#overall youngest countries: 
fig, ax = plt.subplots()
fig.set_size_inches(4,12)
sns.set_context('paper',font_scale=1.5)
ax = sns.barplot(data=df10.head(),y='Team_Region', x='average_age', color='b')
ax.set_title('Top 5 Youngest Countries', fontsize=25)
ax.set_xlabel('Average Age',fontsize=25);
ax.set_ylabel('Country/Region',fontsize=25)
ax.bar_label(ax.containers[0]);

# %%
fig.savefig("q10part1.png",bbox_inches='tight')

# %%
df10bigs=df10[df10['total_athletes']>=1000]
df10bigs.head(12)
# Out:
#      average_age  Team_Region  total_athletes
# 28            23        China            5830
# 55            23  South Korea            4500
# 59            23       Taiwan            1120
# 71            24       Turkey            1383
# 80            24      Romania            4507
# 88            24        Japan            8646
# 100           24       Mexico            2901
# 109           24    Australia            8135
# 111           24       Canada            9831
# 112           24     Bulgaria            3611
# 117           24         Cuba            2503
# 123           24        Egypt            1626

# %%
# youngest countries with over 1000 lifetime competitors: 
fig, ax = plt.subplots()
fig.set_size_inches(4,12)
sns.set_context('paper',font_scale=1.5)
ax = sns.barplot(data=df10bigs.head(10),y='Team_Region', x='average_age', color='b')
ax.set_title('Top 5 Youngest Countries (with over 1000 lifetime competitors)', fontsize=25)
ax.set_xlabel('Average Age',fontsize=25);
ax.set_ylabel('Country/Region',fontsize=25)
ax.bar_label(ax.containers[0]);

# %%
fig.savefig("q10part2.png",bbox_inches='tight')

# %% [markdown]
# ### time for the dreaded q11 query from Heck

# %%
df11 = pd.read_json('./query_json_files/q11.json')
df11.head(1)
# Out:
#         Ev_Sport  Nonmedal average age minus Medalled average age
# 0  Alpine Skiing                                               -1

# %%
# histplot of difference distribution: 
fig, ax = plt.subplots()
fig.set_size_inches(12,8)
sns.set_context('paper',font_scale=1.5)
ax = sns.histplot(data=df11['Nonmedal average age minus Medalled average age'],discrete=True)
ax.set_title('Nonmedalled Avg Age Minus Medalled Avg Age for All Sports', fontsize=25);


ax.set_xlabel('(Average Nonmedalled Age-Average Medalled Age) over all sports',fontsize=20);
ax.set_ylabel('Number of Sports',fontsize=20);

# %%
fig.savefig("q11.png",bbox_inches='tight')

# %% [markdown]
# ### go back and look at team percentage by country:

# %%
teen = pd.read_json('./query_json_files/teen.json')
teen.head(1)
# Out:
#         Team_Region  total_in_region  Teen_Percentage
# 0  Marshall Islands               14            28.57

# %%
#overall youngest countries: 
fig, ax = plt.subplots()
fig.set_size_inches(4,12)
sns.set_context('paper',font_scale=1.5)
ax = sns.barplot(data=teen.head(),y='Team_Region', x='Teen_Percentage', color='b')
ax.set_title('Top 5 Youngest Countries based on Teen Percentage', fontsize=25)
ax.set_xlabel('Teen Percentage',fontsize=25);
ax.set_ylabel('Country/Region',fontsize=25)
ax.bar_label(ax.containers[0]);

# %%
fig.savefig("teen1.png",bbox_inches='tight')

# %%
teenBigs=teen[teen['total_in_region']>=1000]
teenBigs.head(10)
# Out:
#     Team_Region  total_in_region  Teen_Percentage
# 37       Taiwan             1120            10.00
# 44        China             5830             9.16
# 49       Mexico             2901             8.38
# 56      Romania             4507             7.81
# 57  South Korea             4500             7.71
# 74    Australia             8135             6.50
# 75     Bulgaria             3611             6.40
# 86       Canada             9831             5.94
# 91        Spain             5325             5.45
# 93      Hungary             6749             5.36

# %%
russia = teen[teen['Team_Region']=='Russia']
russia.head()
# Out:
#     Team_Region  total_in_region  Teen_Percentage
# 122      Russia            12103             4.08

# %%
#teen heavy countries excluding small countries: 
fig, ax = plt.subplots()
fig.set_size_inches(4,12)
sns.set_context('paper',font_scale=1.5)
ax = sns.barplot(data=teenBigs.head(),y='Team_Region', x='Teen_Percentage', color='b')
ax.set_title('Top 5 Youngest Countries based on Teen Percentage\n (countries over 1000 competitors)', fontsize=25)
ax.set_xlabel('Teen Percentage',fontsize=25);
ax.set_ylabel('Country/Region',fontsize=25)
ax.bar_label(ax.containers[0]);

# %%
fig.savefig("teen2.png",bbox_inches='tight')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
sns.set_context('paper',font_scale=2)
ax = sns.scatterplot(data=teen, x='total_in_region', y='Teen_Percentage',s=200)
ax.set_title('Participation in Olympics vs Teen Percentage by Country', fontsize=25)
ax.set_xlabel('Number of Athlete-Events in Olympic History (by Country)',fontsize=20)
ax.set_ylabel('Teen Percentage of Athletes (in Country)',fontsize=20);

# %%
fig.savefig("teen3.png",bbox_inches='tight')
